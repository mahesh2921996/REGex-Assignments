# %% [markdown]
# <h2>Task - 8<h/2>
#
# <h2> Register Id: SIRSS2292
#
#
# Name: Mahesh Deshmukh</h2>

# %% [markdown]
# <b>Heart Attack Analysis & Prediction</b>
#
#
# - Analysis & Predict Heart Attack based on Age, Gender, No. of disease they have and some other aspects
#
# Description: https://www.kaggle.com/rashikrahmanpritom/heart-attack-analysis-prediction-dataset/tasks?taskId=3833

# %%
# load the libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# here cp - Chest Pain (0: typical angina, 1: atypical angina, 2: non-anginal pain, 3: asymptomatic) , trtbps - resting blood pressure (in mm Hg), chol - cholestoral in mg/dl fetched via BMI sensor, fbs - (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false), restecg - resting electrocardiographic results, thalachh - maximum heart rate achieved, exng - exercise induced angina (1 = yes; 0 = no), oldpeak - Previous peak, slp - Slope, caa - number of major vessels (0-3), thall - Thal rate, output - Target variable (0= less chance of heart attack 1= more chance of heart attack)

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# here, no null value present in this dataset.

# %%
# duplicate data
df.duplicated().sum()
# Out:
# 1

# %% [markdown]
# here, only one duplicate value present. so this remove duplcate value.

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (302, 14)

# %% [markdown]
# ### data visualization

# %%
df.hist(bins=50,figsize=(20,20))
plt.show()

# %% [markdown]
# From graph, most people age has range between 50-60 yrs, the most people has male, the most Chest Pain has typical angina, the most people has resting blood pressure (in mm Hg) between range 120-140 mm, the most cholestoral range has 200-280 mg/dl, the most people has not fasting blood sugar above 120 mg/dl, the most people has maximum heart rate achieved between range 130-175,
# the most people does not exercise induced angina. the most people has number of major vessels is 0. the most thal rate has 2.

# %%
sns.scatterplot(x=df['age'], y=df['chol'], hue=df['sex'], data=df,alpha=0.85)
plt.title('Age vs Cholestoral')
plt.show()

# %%
sns.scatterplot(x=df['age'], y=df['trtbps'], hue=df['sex'], data=df,alpha=0.85)
plt.title('Age vs trtbps')
plt.show()

# %%
sns.scatterplot(x=df['age'], y=df['thalachh'], hue=df['sex'], data=df,alpha=0.85)
plt.title('Age vs thalachh')
plt.show()

# %%
sns.scatterplot(x=df['age'], y=df['oldpeak'], hue=df['sex'], data=df,alpha=0.85)
plt.title('Age vs oldpeak')
plt.show()

# %%
sns.barplot(x=df['output'],y=df['age'],hue=df['sex'],data=df)
plt.xticks(rotation = 90)
plt.show()

# %%
major_age = df[['age','output']].groupby(['output']).mean()

# %%
major_age
# Out:
#               age
# output
# 0       56.601449
# 1       52.585366

# %% [markdown]
# Here, most chance of attack has arrived in major of 52 years old people.

# %%
plt.figure(figsize=(8,8))
sns.countplot(x=df['cp'],hue=df['output'],data=df)
plt.title('distribution of chest pain')
plt.show()

# %% [markdown]
#  here only typical angina type of chest pain is less death as compared to another type of chest pain.

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
min(df1.trtbps)
# Out:
# 94

# %%
max(df1.trtbps)
# Out:
# 200

# %%
df1.loc[(df1.trtbps>94) & (df1.trtbps<124), 'trtbps']=1
df1.loc[(df1.trtbps>=124) & (df1.trtbps<154), 'trtbps']=2
df1.loc[(df1.trtbps>=154) & (df1.trtbps<174), 'trtbps']=3
df1.loc[(df1.trtbps>=174) & (df1.trtbps<201), 'trtbps']=4

# %%
df1['trtbps'] = df1['trtbps'].astype(int)

# %%
sns.countplot(x=df1['trtbps'],hue=df1.output,data=df1)
plt.title('distribution of resting blood pressure with restpect to Heart attack')
plt.show()

# %% [markdown]
#  Major peoples died in blood pressure between range 94 to 154 in mm Hg.

# %%
df.corr()
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trtbps    0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalachh -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exng      0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slp      -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# caa       0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thall     0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
X = df.iloc[:,:-1]

# %%
X.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall
# 0    0      1
# 1    0      2
# 2    0      2
# 3    0      2
# 4    0      2

# %%
Y = df.iloc[:,-1]

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: output, dtype: int64

# %%
# Split the data into train and test data:
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30, random_state=42)

# %%
X_train.shape
# Out:
# (211, 13)

# %%
X_test.shape
# Out:
# (91, 13)

# %%
y_train.shape
# Out:
# (211,)

# %%
y_test.shape
# Out:
# (91,)

# %%
# Build the model with the Logistic regression algorithm:
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\91950\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
# accuracy score
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8241758241758241

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[34,  8],
#        [ 8, 41]], dtype=int64)

# %% [markdown]
# Here, the False positive value is 8. we can say, 19.04% chance to people will come to more chances of a heart attack but our model predicts those people have less chance of heart attack.

# %%
# all report
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred,target_names=['less chance of heart attack','more chance of heart attack']))
# Out:
#                              precision    recall  f1-score   support
#
# less chance of heart attack       0.81      0.81      0.81        42
# more chance of heart attack       0.84      0.84      0.84        49
#
#                    accuracy                           0.82        91
#                   macro avg       0.82      0.82      0.82        91
#                weighted avg       0.82      0.82      0.82        91

# %%
# Thank you for your time!
